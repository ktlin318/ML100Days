# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y-yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 251.194
# The Mean absolute error is 12.154

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：<br>
#
# Fashion MNIST<br>
# https://www.kaggle.com/zalando-research/fashionmnist <br>
#
# 1. 你選的這組資料為何重要<br>
# 原始的MNIST數據集過於簡單，也被過度使用，多數的ML方法可達到非常高的準確率。<br>
# 而相較於原始的MNIST數據集，Fashion MNIST數據集資料較為複雜，作為初步測試的數據集來說較具意義。<br>
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<br>
# 提供者為Zalando research，Zalando為德國一家時尚電子商務網際網路公司。<br>
# 蒐集不同的時尚服裝、鞋款或配件等28x28的灰階圖示。<br>
#
# 3. 蒐集而來的資料型態為何<br>
# 原始塗視為非結構化資料，而這個kaggle上的數據集經過轉換後變成結構化的CSV資料。<br>
#
# 4. 這組資料想解決的問題如何評估<br>
# 解決手寫數字MNIST數據集被過度使用的問題，並使用較複雜的數據集欲取代原始的MNIST數據集，提供一個較有意義的測試數據集。<br>
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<br>
# 核心問題：提升車隊的業績，就是要降低車隊的空車率。<br>
# 假設：假設某些時段某個地區可能是載客需求量大的地方，可以將這些資訊提供給司機們，以減少在路上空車的時間。<br>
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)<br>
# 透過計程車的儀表板蒐集各時間每名司機的載客時間、載客時長、載客人數、空車時間、載客地點、目的地、收益、日期等。<br>
#
# 3. 蒐集而來的資料型態為何<br>
# 蒐集來的資料應彙整成表格，所以應為結構化資料。<br>
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)<br>
# 根據這些資料，我們可以分析是否那些時段載客需求量大增，那些地點又是載客率最高的地方，甚至於某些地方的客人所提供的平均收益更高等來制定提升業績的方案。
